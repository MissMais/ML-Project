# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score
from math import sqrt

# %%
ticker = "AAPL"
start = "2023-12-20"
end = "2024-01-20"
interval = '30m'

# %%
df = yf.download(ticker, start=start, end=end, interval=interval)
df.tail(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: 15m data not available for startTime=1701406800 and endTime=1705726800. The requested range must be within the last 60 days.')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
ClosingPrice = df['Close']

print(ClosingPrice.values.shape)

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(ClosingPrice.values.reshape(-1, 1))
# print(scaled_data)
# Out:
# (1711,)

# %%
plt.plot(scaled_data)
plt.title(f'{ticker} Closing Price')
plt.show()

# %%
training_data_len = int(len(scaled_data) * 0.8)

training_data = scaled_data[0:training_data_len, :]
testing_data = scaled_data[training_data_len:, :]

len(training_data), len(testing_data)
# Out:
# (1368, 343)

# %%
past_values = 1

def create_training_data(data, past_values):
    if len(data) < past_values:
        return np.array([]), np.array([])
    X_train = []
    y_train = []
    for i in range(past_values, len(data)):
        X_train.append(data[i-past_values:i, 0])
        y_train.append(data[i, 0])
    return np.array(X_train), np.array(y_train)

X_train, y_train = create_training_data(training_data, past_values)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, y_test = create_training_data(testing_data, past_values)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
len(X_train) + len(X_test), len(scaled_data)
# Out:
# (1709, 1711)

# %%
X_train.shape
# Out:
# (1367, 1, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=200, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 11s 19ms/step - loss: 0.1661
# Epoch 2/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1230
# Epoch 3/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0878
# Epoch 4/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0725
# Epoch 5/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0696
# Epoch 6/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0588
# Epoch 7/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0451
# Epoch 8/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0274
# Epoch 9/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0094
# Epoch 10/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 11/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0028
# Epoch 12/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 13/200
# 7/7 [==============================] - 0s 12ms/step - loss: 5.1778e-04
# Epoch 14/200
# 7/7 [==============================] - 0s 13ms/step - loss: 7.1152e-04
# Epoch 15/200
# 7/7 [==============================] - 0s 14ms/step - loss: 4.9171e-04
# Epoch 16/200
# 7/7 [==============================] - 0s 13ms/step - loss: 4.0869e-04
# Epoch 17/200
# 7/7 [==============================] - 0s 12ms/step - loss: 4.1900e-04
# Epoch 18/200
# 7/7 [==============================] - 0s 11ms/step - loss: 3.7885e-04
# Epoch 19/200
# 7/7 [==============================] - 0s 11ms/step - loss: 3.7110e-04
# Epoch 20/200
# 7/7 [==============================] - 0s 11ms/step - loss: 3.5853e-04
# Epoch 21/200
# 7/7 [==============================] - 0s 13ms/step - loss: 3.4367e-04
# Epoch 22/200
# 7/7 [==============================] - 0s 11ms/step - loss: 3.3776e-04
# Epoch 23/200
# 7/7 [==============================] - 0s 12ms/step - loss: 3.2623e-04
# Epoch 24/200
# 7/7 [==============================] - 0s 14ms/step - loss: 3.1656e-04
# Epoch 25/200
# 7/7 [==============================] - 0s 12ms/step - loss: 3.0931e-04
# Epoch 26/200
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0037e-04
# Epoch 27/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.9561e-04
# Epoch 28/200
# 7/7 [==============================] - 0s 10ms/step - loss: 2.8616e-04
# Epoch 29/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.7822e-04
# Epoch 30/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.7045e-04
# Epoch 31/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.6775e-04
# Epoch 32/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.5967e-04
# Epoch 33/200
# 7/7 [==============================] - 0s 10ms/step - loss: 2.5243e-04
# Epoch 34/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4318e-04
# Epoch 35/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.3827e-04
# Epoch 36/200
# 7/7 [==============================] - 0s 12ms/step - loss: 2.3191e-04
# Epoch 37/200
# 7/7 [==============================] - 0s 13ms/step - loss: 2.2742e-04
# Epoch 38/200
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2222e-04
# Epoch 39/200
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1669e-04
# Epoch 40/200
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1323e-04
# Epoch 41/200
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0827e-04
# Epoch 42/200
# 7/7 [==============================] - 0s 10ms/step - loss: 2.0194e-04
# Epoch 43/200
# 7/7 [==============================] - 0s 15ms/step - loss: 2.
200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4443e-04
# Epoch 153/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5312e-04
# Epoch 154/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5072e-04
# Epoch 155/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4410e-04
# Epoch 156/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4440e-04
# Epoch 157/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4399e-04
# Epoch 158/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4578e-04
# Epoch 159/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4278e-04
# Epoch 160/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4430e-04
# Epoch 161/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4330e-04
# Epoch 162/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4239e-04
# Epoch 163/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4444e-04
# Epoch 164/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4243e-04
# Epoch 165/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.4306e-04
# Epoch 166/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4316e-04
# Epoch 167/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4317e-04
# Epoch 168/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4249e-04
# Epoch 169/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4452e-04
# Epoch 170/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4612e-04
# Epoch 171/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4325e-04
# Epoch 172/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4520e-04
# Epoch 173/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4415e-04
# Epoch 174/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4289e-04
# Epoch 175/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4274e-04
# Epoch 176/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4556e-04
# Epoch 177/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4809e-04
# Epoch 178/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4859e-04
# Epoch 179/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4447e-04
# Epoch 180/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4680e-04
# Epoch 181/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4489e-04
# Epoch 182/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4746e-04
# Epoch 183/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4372e-04
# Epoch 184/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4338e-04
# Epoch 185/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4834e-04
# Epoch 186/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.6352e-04
# Epoch 187/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.5385e-04
# Epoch 188/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4507e-04
# Epoch 189/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.4459e-04
# Epoch 190/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4217e-04
# Epoch 191/200
# 7/7 [==============================] - 0s 12ms/step - loss: 1.4880e-04
# Epoch 192/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.4924e-04
# Epoch 193/200
# 7/7 [==============================] - 0s 12ms/step - loss: 1.4934e-04
# Epoch 194/200
# 7/7 [==============================] - 0s 13ms/step - loss: 1.4443e-04
# Epoch 195/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4565e-04
# Epoch 196/200
# 7/7 [==============================] - 0s 12ms/step - loss: 1.4343e-04
# Epoch 197/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4450e-04
# Epoch 198/200
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4532e-04
# Epoch 199/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5530e-04
# Epoch 200/200
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5488e-04

# %%
pred_train = model.predict(X_train)
pred = model.predict(X_test)
# Out:
# 43/43 [==============================] - 2s 4ms/step
# 11/11 [==============================] - 0s 3ms/step

# %%
pred_train = scaler.inverse_transform(pred_train)
pred = scaler.inverse_transform(pred)
y_test = scaler.inverse_transform([y_test])
y_train = scaler.inverse_transform([y_train])

# %%
y_test = y_test.flatten()
y_train = y_train.flatten()

# %%
print("Training Error")
mae = mean_absolute_error(y_train, pred_train)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_train, pred_train))
print("Root Mean Squared Error (RMSE):", rmse)
    
plt.plot(y_train, label = 'actual '+str(ticker))
plt.plot(pred_train, label = 'predicted '+str(ticker))
plt.title("Training Plot")
plt.legend()
plt.show()
# Out:
# Training Error
# Mean Absolute Error (MAE): 1.2537506455126342
# Root Mean Squared Error (RMSE): 1.9470352541880858

# %%
print("Testing Error")
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_test, pred))
print("Root Mean Squared Error (RMSE):", rmse)

plt.plot(y_test, label = 'actual '+str(ticker))
plt.plot(pred, label = 'predicted '+str(ticker))
plt.title("Testing Plot")
plt.legend()
plt.show()
# Out:
# Testing Error
# Mean Absolute Error (MAE): 2.0117107636747305
# Root Mean Squared Error (RMSE): 2.676120467005711

# %% [markdown]
# ## 10 days future prediction without correction

# %%
scaled_data
# Out:
# array([[0.00463361],
#        [0.00627533],
#        [0.0051246 ],
#        ...,
#        [0.90530252],
#        [0.9418191 ],
#        [0.95980114]])

# %%
len(X_train) + len(X_test),  len(scaled_data)
# Out:
# (1709, 1711)

# %%
reshaped_data = scaled_data.reshape(scaled_data.shape[0], scaled_data.shape[1], 1)

# %%
future_data_to_predict = reshaped_data[-10:]
future_data_to_predict
# Out:
# array([[[0.89609668]],
#
#        [[0.92297777]],
#
#        [[0.92040014]],
#
#        [[0.92684425]],
#
#        [[0.92316188]],
#
#        [[0.92518717]],
#
#        [[0.91113296]],
#
#        [[0.90530252]],
#
#        [[0.9418191 ]],
#
#        [[0.95980114]]])

# %%
X_test.ndim, reshaped_data.ndim
# Out:
# (3, 3)

# %%
def predict_future(last_input):
    
    res = model.predict(last_input)
    Output = scaler.inverse_transform(res)
    return Output

future_predictions_1 = predict_future(future_data_to_predict)
# print(future_predictions_1)

future_predictions_1 = future_predictions_1.flatten()
print(future_predictions_1)
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [180.55971 184.76192 184.35968 185.36494 184.79062 185.10655 182.91232
#  182.0007  187.6972  190.49066]

# %%
# def predict_future(last_input):
    
#     res = model.predict(last_input)
#     Output = scaler.inverse_transform(res)
#     return Output

# future_predictions_2 = predict_future(X_test[-5:])
# # print(future_predictions_2)

# future_predictions_2 = future_predictions_2.flatten()
# print(future_predictions_2)

# %%
day=range(1,(len(future_data_to_predict)+1))

# %%
plt.plot(day, future_predictions_1, color='red', label='scaled_data')
# plt.plot(day, future_predictions_2, color='blue', label='x_test')
plt.legend()
plt.show()

# %%
# ticker = "AAPL"
# start='2024-01-22'
# end='2024-01-26'
# df = yf.download(ticker, start=start, end=end)
# # print(df)
# actual = df['Close'].values
# print(actual)

# %%
# day_actual = np.arange(1,21)
# day_pred = np.arange(1,21)

# %%
# plt.figure(figsize=(8,6))
# plt.title(f'Plot for {ticker} from {start} till {end}')
# plt.xlabel('No. of Days')
# plt.ylabel('Price Values')
# plt.plot(day_actual, actual, label = 'actual price', color='blue')
# plt.plot(day_pred, future_predictions_1, label = 'predicted price', color='red')
# plt.legend()
# plt.show()

# %%
def get_control_vector(val):
    return np.diff(np.sign(np.diff(val)))

def buy_and_sell_bot(val,controls):
    inv = []
    curr_val = 1000
    inds = np.where(controls)[0]
    buy_inds = np.where(controls>0)[0]
    sell_inds = np.where(controls<0)[0]
    max_limit = sell_inds[-1] if sell_inds[-1]>buy_inds[-1] else buy_inds[-1]
    for i in range(buy_inds[0]+2):
        inv.append(curr_val)
    for i in range(buy_inds[0],max_limit+1):
        if controls[i]>0:
            buy_val = val[i+1]
        elif controls[i]<0:
            sell_val = val[i+1]
            curr_val = curr_val*sell_val/buy_val
        inv.append(curr_val)
        
    if max_limit+1!=len(controls):
        for i in range(len(controls)-max_limit-1):
            inv.append(curr_val)
    return inv

# def buy_and_sell_bot(val, controls):
#     inv = []
#     curr_val = 1000
#     buy_inds = np.where(controls > 0)[0]
#     sell_inds = np.where(controls < 0)[0]
    
#     if buy_inds.size == 0 or sell_inds.size == 0:
#         return [curr_val] * len(controls)
    
#     max_limit = max(sell_inds[-1], buy_inds[-1])
#     for i in range(buy_inds[0] + 2):
#         inv.append(curr_val)
        
#     for i in range(buy_inds[0], max_limit + 1):
#         if controls[i] > 0:
#             buy_val = val[i + 1]
#         elif controls[i] < 0:
#             sell_val = val[i + 1]
#             curr_val = curr_val * sell_val / buy_val
#         inv.append(curr_val)
        
#     if max_limit + 1 != len(controls):
#         for i in range(len(controls) - max_limit - 1):
#             inv.append(curr_val)
    
#     return inv

# %%
controls_pred= get_control_vector(future_predictions_1)
amount_pred = buy_and_sell_bot(future_predictions_1, controls_pred)
controls_pred, amount_pred
# Out:
# (array([-2.,  2., -2.,  2., -2.,  0.,  2.,  0.], dtype=float32),
#  [1000,
#   1000,
#   1000,
#   1000,
#   1005.4527339235351,
#   1005.4527339235351,
#   1007.1717385421862,
#   1007.1717385421862,
#   1007.1717385421862,
#   1007.1717385421862])

# %%
# controls_actual= get_control_vector(actual)
# amount_actual = buy_and_sell_bot(actual, controls_actual)
# controls_actual, amount_actual

# %%
# plt.plot(amount_actual, label="actual")
plt.plot(amount_pred, label="pred")
plt.legend()
plt.title(f"{ticker} Returns")
plt.show()

# %% [markdown]
# ### Price values along with dates

# %%
from datetime import datetime, timedelta
count=31
Date = []
for i in range(22,34):
    if i == 27:
        continue
    elif i == 28:
        continue
    elif i >= 32:
        i = i-count
        base_date = datetime(2024,2,i)
        formatted_date = base_date.strftime('%d-%m-%Y')
        Date.append(formatted_date)
    else:
        base_date = datetime(2024,1,i)
        formatted_date = base_date.strftime('%d-%m-%Y')
        Date.append(formatted_date)

# %%
price_value_dict = {}
price_value_dict['Date'] = Date
price_value_dict['Closing Price'] = future_predictions_1.tolist()

# %%
price_value_dict
# Out:
# {'Date': ['22-01-2024',
#   '23-01-2024',
#   '24-01-2024',
#   '25-01-2024',
#   '26-01-2024',
#   '29-01-2024',
#   '30-01-2024',
#   '31-01-2024',
#   '01-02-2024',
#   '02-02-2024'],
#  'Closing Price': [180.55970764160156,
#   184.7619171142578,
#   184.35968017578125,
#   185.3649444580078,
#   184.79061889648438,
#   185.10655212402344,
#   182.91232299804688,
#   182.00070190429688,
#   187.69720458984375,
#   190.49066162109375]}

# %%
Price_with_dates = pd.DataFrame(price_value_dict)

# %%
Price_with_dates.columns = pd.MultiIndex.from_tuples([(f'{ticker}', 'Date'), (f'{ticker}', 'Closing Price')])

# %%
Price_with_dates
# Out:
#          AAPL
#          Date Closing Price
# 0  22-01-2024    180.559708
# 1  23-01-2024    184.761917
# 2  24-01-2024    184.359680
# 3  25-01-2024    185.364944
# 4  26-01-2024    184.790619
# 5  29-01-2024    185.106552
# 6  30-01-2024    182.912323
# 7  31-01-2024    182.000702
# 8  01-02-2024    187.697205
# 9  02-02-2024    190.490662

# %%
ticker = "AAPL"
start = "2024-01-22"
end = "2024-01-31"

# %%
df = yf.download(ticker, start=start, end=end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-01-22  192.300003  195.330002  192.259995  193.889999  193.889999
# 2024-01-23  195.020004  195.750000  193.830002  195.179993  195.179993
# 2024-01-24  195.419998  196.380005  194.339996  194.500000  194.500000
# 2024-01-25  195.220001  196.270004  193.110001  194.169998  194.169998
# 2024-01-26  194.270004  194.759995  191.940002  192.419998  192.419998
# 2024-01-29  192.009995  192.199997  189.580002  191.729996  191.729996
# 2024-01-30  190.940002  191.800003  188.654999  188.949997  188.949997
#
#               Volume
# Date
# 2024-01-22  60133900
# 2024-01-23  42355600
# 2024-01-24  53631300
# 2024-01-25  54822100
# 2024-01-26  44553400
# 2024-01-29  47042500
# 2024-01-30  15451661

# %%
actual_data = df['Close'].values

# %%
day_actual = range(1,8)
day_predicted = range(1,11)

# %%
plt.plot(day_actual, actual_data, color='red', label='actual')
plt.plot(day_predicted, future_predictions_1, color='blue', label='predicted')
plt.legend()
plt.show()
