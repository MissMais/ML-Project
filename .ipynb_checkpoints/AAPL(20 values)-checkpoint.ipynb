# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score
from math import sqrt

# %%
ticker = "AAPL"
start = "2023-12-20"
end = "2024-01-20"

# %%
df = yf.download(ticker, start=start, end=end, interval="30m")
df.tail(13)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                            Open        High         Low       Close  \
# Datetime
# 2024-01-19 09:30:00  189.330002  189.879807  188.820007  189.600006
# 2024-01-19 10:00:00  189.584793  189.964996  188.910004  189.940094
# 2024-01-19 10:30:00  189.940002  190.160004  189.619995  189.789993
# 2024-01-19 11:00:00  189.779999  190.059998  189.580002  189.910004
# 2024-01-19 11:30:00  189.899994  190.029999  189.330093  189.975006
# 2024-01-19 12:00:00  189.975006  190.429993  189.899994  190.315002
# 2024-01-19 12:30:00  190.320007  190.639999  190.279999  190.565002
# 2024-01-19 13:00:00  190.565002  190.990005  190.494995  190.934998
# 2024-01-19 13:30:00  190.934494  191.449997  190.925003  191.414001
# 2024-01-19 14:00:00  191.410095  191.949997  191.369995  191.470001
# 2024-01-19 14:30:00  191.479996  191.669998  191.169998  191.649994
# 2024-01-19 15:00:00  191.653793  191.740005  191.320007  191.434998
# 2024-01-19 15:30:00  191.434296  191.820007  191.320007  191.580002
#
#                       Adj Close    Volume
# Datetime
# 2024-01-19 09:30:00  189.600006  12242124
# 2024-01-19 10:00:00  189.940094   4140639
# 2024-01-19 10:30:00  189.789993   4541610
# 2024-01-19 11:00:00  189.910004   3031544
# 2024-01-19 11:30:00  189.975006   2710933
# 2024-01-19 12:00:00  190.315002   3276207
# 2024-01-19 12:30:00  190.565002   2489255
# 2024-01-19 13:00:00  190.934998   4695640
# 2024-01-19 13:30:00  191.414001   2995274
# 2024-01-19 14:00:00  191.470001   3854901
# 2024-01-19 14:30:00  191.649994   3406396
# 2024-01-19 15:00:00  191.434998   3031865
# 2024-01-19 15:30:00  191.580002   5716572

# %%
ClosingPrice = df['Close']

print(ClosingPrice.values.shape)

scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(ClosingPrice.values.reshape(-1, 1))
# print(scaled_data)
# Out:
# (260,)

# %%
plt.plot(scaled_data)
plt.title(f'{ticker} Closing Price')
plt.show()

# %%
training_data_len = int(len(scaled_data) * 0.8)

training_data = scaled_data[0:training_data_len, :]
testing_data = scaled_data[training_data_len:, :]

len(training_data), len(testing_data)
# Out:
# (1352, 339)

# %%
past_values = 1

def create_training_data(data, past_values):
    if len(data) < past_values:
        return np.array([]), np.array([])
    X_train = []
    y_train = []
    for i in range(past_values, len(data)):
        X_train.append(data[i-past_values:i, 0])
        y_train.append(data[i, 0])
    return np.array(X_train), np.array(y_train)

X_train, y_train = create_training_data(training_data, past_values)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test, y_test = create_training_data(testing_data, past_values)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
len(X_train) + len(X_test), len(scaled_data)
# Out:
# (1689, 1691)

# %%
X_train.shape
# Out:
# (1351, 1, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=200, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 5s 8ms/step - loss: 0.1610
# Epoch 2/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1192
# Epoch 3/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0860
# Epoch 4/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0704
# Epoch 5/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0691
# Epoch 6/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0594
# Epoch 7/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0472
# Epoch 8/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0311
# Epoch 9/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0129
# Epoch 10/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 11/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0023
# Epoch 12/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 13/200
# 7/7 [==============================] - 0s 7ms/step - loss: 4.8362e-04
# Epoch 14/200
# 7/7 [==============================] - 0s 7ms/step - loss: 6.8133e-04
# Epoch 15/200
# 7/7 [==============================] - 0s 8ms/step - loss: 5.2143e-04
# Epoch 16/200
# 7/7 [==============================] - 0s 7ms/step - loss: 3.8792e-04
# Epoch 17/200
# 7/7 [==============================] - 0s 8ms/step - loss: 3.9990e-04
# Epoch 18/200
# 7/7 [==============================] - 0s 7ms/step - loss: 3.6832e-04
# Epoch 19/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.4918e-04
# Epoch 20/200
# 7/7 [==============================] - 0s 8ms/step - loss: 3.4193e-04
# Epoch 21/200
# 7/7 [==============================] - 0s 8ms/step - loss: 3.2783e-04
# Epoch 22/200
# 7/7 [==============================] - 0s 9ms/step - loss: 3.2225e-04
# Epoch 23/200
# 7/7 [==============================] - 0s 6ms/step - loss: 3.1355e-04
# Epoch 24/200
# 7/7 [==============================] - 0s 8ms/step - loss: 3.0549e-04
# Epoch 25/200
# 7/7 [==============================] - 0s 9ms/step - loss: 2.
200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4560e-04
# Epoch 133/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4553e-04
# Epoch 134/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4464e-04
# Epoch 135/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4377e-04
# Epoch 136/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4133e-04
# Epoch 137/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4244e-04
# Epoch 138/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4253e-04
# Epoch 139/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4266e-04
# Epoch 140/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4184e-04
# Epoch 141/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4230e-04
# Epoch 142/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4197e-04
# Epoch 143/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4387e-04
# Epoch 144/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4606e-04
# Epoch 145/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4233e-04
# Epoch 146/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4416e-04
# Epoch 147/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4585e-04
# Epoch 148/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4441e-04
# Epoch 149/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4252e-04
# Epoch 150/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4378e-04
# Epoch 151/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4665e-04
# Epoch 152/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4655e-04
# Epoch 153/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4311e-04
# Epoch 154/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4799e-04
# Epoch 155/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4609e-04
# Epoch 156/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4377e-04
# Epoch 157/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4814e-04
# Epoch 158/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4367e-04
# Epoch 159/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4545e-04
# Epoch 160/200
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4313e-04
# Epoch 161/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4213e-04
# Epoch 162/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4183e-04
# Epoch 163/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4212e-04
# Epoch 164/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4168e-04
# Epoch 165/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4356e-04
# Epoch 166/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4673e-04
# Epoch 167/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4980e-04
# Epoch 168/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4606e-04
# Epoch 169/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4879e-04
# Epoch 170/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4534e-04
# Epoch 171/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4505e-04
# Epoch 172/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4744e-04
# Epoch 173/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4672e-04
# Epoch 174/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4378e-04
# Epoch 175/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4322e-04
# Epoch 176/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4275e-04
# Epoch 177/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4231e-04
# Epoch 178/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4414e-04
# Epoch 179/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4829e-04
# Epoch 180/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5330e-04
# Epoch 181/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4646e-04
# Epoch 182/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4180e-04
# Epoch 183/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5082e-04
# Epoch 184/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4798e-04
# Epoch 185/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.6117e-04
# Epoch 186/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5075e-04
# Epoch 187/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4394e-04
# Epoch 188/200
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4407e-04
# Epoch 189/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4651e-04
# Epoch 190/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4982e-04
# Epoch 191/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4501e-04
# Epoch 192/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4593e-04
# Epoch 193/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4241e-04
# Epoch 194/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4283e-04
# Epoch 195/200
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4238e-04
# Epoch 196/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4943e-04
# Epoch 197/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5208e-04
# Epoch 198/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5519e-04
# Epoch 199/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.5300e-04
# Epoch 200/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.4382e-04

# %%
pred_train = model.predict(X_train)
pred = model.predict(X_test)
# Out:
# 43/43 [==============================] - 1s 3ms/step
# 11/11 [==============================] - 0s 3ms/step

# %%
pred_train = scaler.inverse_transform(pred_train)
pred = scaler.inverse_transform(pred)
y_test = scaler.inverse_transform([y_test])
y_train = scaler.inverse_transform([y_train])

# %%
y_test = y_test.flatten()
y_train = y_train.flatten()

# %%
print("Training Error")
mae = mean_absolute_error(y_train, pred_train)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_train, pred_train))
print("Root Mean Squared Error (RMSE):", rmse)
    
plt.plot(y_train, label = 'actual '+str(ticker))
plt.plot(pred_train, label = 'predicted '+str(ticker))
plt.title("Training Plot")
plt.legend()
plt.show()
# Out:
# Training Error
# Mean Absolute Error (MAE): 1.242570206467793
# Root Mean Squared Error (RMSE): 1.9399141834202078

# %%
print("Testing Error")
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_test, pred))
print("Root Mean Squared Error (RMSE):", rmse)

plt.plot(y_test, label = 'actual '+str(ticker))
plt.plot(pred, label = 'predicted '+str(ticker))
plt.title("Testing Plot")
plt.legend()
plt.show()
# Out:
# Testing Error
# Mean Absolute Error (MAE): 2.0315713826015855
# Root Mean Squared Error (RMSE): 2.672255622558017

# %% [markdown]
# ## 10 days future prediction without correction

# %%
scaled_data
# Out:
# array([[0.00463361],
#        [0.00627533],
#        [0.0051246 ],
#        ...,
#        [0.99668594],
#        [0.98637535],
#        [0.99281945]])

# %%
len(X_train), len(X_test),  len(scaled_data)
# Out:
# (1351, 338, 1691)

# %%
reshaped_data = scaled_data.reshape(scaled_data.shape[0], scaled_data.shape[1], 1)

# %%
future_data_to_predict = reshaped_data[-20:]
future_data_to_predict
# Out:
# array([[[0.9541549 ]],
#
#        [[0.95826683]],
#
#        [[0.95004297]],
#
#        [[0.94893822]],
#
#        [[0.95268193]],
#
#        [[0.94636059]],
#
#        [[0.94992019]],
#
#        [[0.95783727]],
#
#        [[0.94672881]],
#
#        [[0.97121638]],
#
#        [[0.96446549]],
#
#        [[0.97643307]],
#
#        [[0.98527069]],
#
#        [[0.96974342]],
#
#        [[0.97913346]],
#
#        [[0.99907945]],
#
#        [[1.        ]],
#
#        [[0.99668594]],
#
#        [[0.98637535]],
#
#        [[0.99281945]]])

# %%
X_test.ndim, reshaped_data.ndim
# Out:
# (3, 3)

# %%
def predict_future(last_input):
    
    res = model.predict(last_input)
    Output = scaler.inverse_transform(res)
    return Output

future_predictions_1 = predict_future(future_data_to_predict)
# print(future_predictions_1)

future_predictions_1 = future_predictions_1.flatten()
print(future_predictions_1)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [189.61946 190.26091 188.97762 188.8051  189.38957 188.40248 188.95845
#  190.19394 188.46004 192.27843 191.22716 193.09007 194.4636  192.04916
#  193.50996 196.60594 196.74861 196.23494 194.63515 195.63533]

# %%
# def predict_future(last_input):
    
#     res = model.predict(last_input)
#     Output = scaler.inverse_transform(res)
#     return Output

# future_predictions_2 = predict_future(X_test[-5:])
# # print(future_predictions_2)

# future_predictions_2 = future_predictions_2.flatten()
# print(future_predictions_2)

# %%
day=range(1,(len(future_data_to_predict)+1))

# %%
plt.plot(day, future_predictions_1, color='red', label='scaled_data')
# plt.plot(day, future_predictions_2, color='blue', label='x_test')
plt.legend()
plt.show()

# %%
ticker = "AAPL"
start='2023-12-20'
end='2024-01-20'
df = yf.download(ticker, start=start, end=end)
# print(df)
actual = df['Close'].values
print(actual)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [194.83000183 194.67999268 193.6000061  193.05000305 193.1499939
#  193.58000183 192.52999878 185.63999939 184.25       181.91000366
#  181.17999268 185.55999756 185.13999939 186.19000244 185.58999634
#  185.91999817 183.63000488 182.67999268 188.63000488 191.55999756]

# %%
day_actual = np.arange(1,21)
day_pred = np.arange(1,21)

# %%
plt.figure(figsize=(8,6))
plt.title(f'Plot for {ticker} from {start} till {end}')
plt.xlabel('No. of Days')
plt.ylabel('Price Values')
plt.plot(day_actual, actual, label = 'actual price', color='blue')
plt.plot(day_pred, future_predictions_1, label = 'predicted price', color='red')
plt.legend()
plt.show()

# %%
def get_control_vector(val):
    return np.diff(np.sign(np.diff(val)))

def buy_and_sell_bot(val,controls):
    inv = []
    curr_val = 1000
    inds = np.where(controls)[0]
    buy_inds = np.where(controls>0)[0]
    sell_inds = np.where(controls<0)[0]
    max_limit = sell_inds[-1] if sell_inds[-1]>buy_inds[-1] else buy_inds[-1]
    for i in range(buy_inds[0]+2):
        inv.append(curr_val)
    for i in range(buy_inds[0],max_limit+1):
        if controls[i]>0:
            buy_val = val[i+1]
        elif controls[i]<0:
            sell_val = val[i+1]
            curr_val = curr_val*sell_val/buy_val
        inv.append(curr_val)
        
    if max_limit+1!=len(controls):
        for i in range(len(controls)-max_limit-1):
            inv.append(curr_val)
    return inv

# %%
controls_pred= get_control_vector(future_predictions_1)
amount_pred = buy_and_sell_bot(future_predictions_1, controls_pred)
controls_pred, amount_pred
# Out:
# (array([-2.,  0.,  2., -2.,  2.,  0., -2.,  2., -2.,  2.,  0., -2.,  2.,
#          0.,  0., -2.,  0.,  2.], dtype=float32),
#  [1000,
#   1000,
#   1000,
#   1000,
#   1000,
#   1003.095640201653,
#   1003.095640201653,
#   1003.095640201653,
#   1012.6337515332908,
#   1012.6337515332908,
#   1033.1507297666637,
#   1033.1507297666637,
#   1033.1507297666637,
#   1050.6363482248544,
#   1050.6363482248544,
#   1050.6363482248544,
#   1050.6363482248544,
#   1076.3454447937718,
#   1076.3454447937718,
#   1076.3454447937718])

# %%
controls_actual= get_control_vector(actual)
amount_actual = buy_and_sell_bot(actual, controls_actual)
controls_actual, amount_actual
# Out:
# (array([ 0.,  0.,  2.,  0., -2.,  0.,  0.,  0.,  0.,  2., -2.,  2., -2.,
#          2., -2.,  0.,  2.,  0.]),
#  [1000,
#   1000,
#   1000,
#   1000,
#   1000,
#   1000,
#   1002.7453963787547,
#   1002.7453963787547,
#   1002.7453963787547,
#   1002.7453963787547,
#   1002.7453963787547,
#   1002.7453963787547,
#   1026.9866476752825,
#   1026.9866476752825,
#   1032.8111000774027,
#   1032.8111000774027,
#   1034.6475651934354,
#   1034.6475651934354,
#   1034.6475651934354,
#   1034.6475651934354])

# %%
plt.plot(amount_actual, label="actual")
plt.plot(amount_pred, label="pred")
plt.legend()
plt.title("Returns")
plt.show()
