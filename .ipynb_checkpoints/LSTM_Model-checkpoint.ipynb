# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score
from math import sqrt

# %%
ticker = "AMZN"
start = "2018-04-01"
end = "2023-10-05"

# %%
df = yf.download(ticker, start=start, end=end)
df.tail(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-09-21  131.940002  132.240005  129.309998  129.330002  129.330002
# 2023-09-22  131.110001  132.029999  128.520004  129.119995  129.119995
# 2023-09-25  129.360001  131.779999  128.770004  131.270004  131.270004
# 2023-09-26  130.119995  130.389999  125.279999  125.980003  125.980003
# 2023-09-27  125.760002  127.480003  124.129997  125.980003  125.980003
# 2023-09-28  124.040001  126.580002  123.040001  125.980003  125.980003
# 2023-09-29  128.199997  129.149994  126.320000  127.120003  127.120003
# 2023-10-02  127.279999  130.470001  126.540001  129.460007  129.460007
# 2023-10-03  128.059998  128.520004  124.250000  124.720001  124.720001
# 2023-10-04  126.059998  127.360001  125.680000  127.000000  127.000000
#
#               Volume
# Date
# 2023-09-21  70234800
# 2023-09-22  59904300
# 2023-09-25  46017800
# 2023-09-26  73048200
# 2023-09-27  66553400
# 2023-09-28  54555000
# 2023-09-29  62377600
# 2023-10-02  48029700
# 2023-10-03  51565000
# 2023-10-04  44203900

# %%
data = df['Close']
# print(data)
print(data.values.shape)
scaler = MinMaxScaler()
data = scaler.fit_transform(data.values.reshape(-1, 1))
# print(data)
# Out:
# (1388,)

# %%
plt.plot(data)
plt.title('Amazon Closing Price')
plt.show()

# %%
training_data_len = int(len(data) * 0.8)
# print(training_data_len)
training_data = data[0:training_data_len, :]
testing_data = data[training_data_len:, :]

len(training_data), len(testing_data)
# Out:
# (1110, 278)

# %%
past_values = 1

def create_training_data(data, past_values):
    if len(data) < past_values:
        return np.array([]), np.array([])
    X_train = []
    y_train = []
    for i in range(past_values, len(data)):
        X_train.append(data[i-past_values:i, 0])
        y_train.append(data[i, 0])
    return np.array(X_train), np.array(y_train)

X_train, y_train = create_training_data(training_data, past_values)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test_1, y_test = create_training_data(testing_data, past_values)
X_test = np.reshape(X_test_1, (X_test_1.shape[0], X_test_1.shape[1], 1))

# %%
X_train.shape
# Out:
# (1109, 1, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=200, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 13s 15ms/step - loss: 0.2896
# Epoch 2/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2321
# Epoch 3/200
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1751
# Epoch 4/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.1187
# Epoch 5/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0774
# Epoch 6/200
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0686
# Epoch 7/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0706
# Epoch 8/200
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0588
# Epoch 9/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0511
# Epoch 10/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0434
# Epoch 11/200
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0327
# Epoch 12/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0230
# Epoch 13/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0133
# Epoch 14/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0060
# Epoch 15/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0020
# Epoch 16/200
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 17/200
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 18/200
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 19/200
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 20/200
# 6/6 [==============================] - 0s 10ms/step - loss: 9.7753e-04
# Epoch 21/200
# 6/6 [==============================] - 0s 10ms/step - loss: 9.3937e-04
# Epoch 22/200
# 6/6 [==============================] - 0s 12ms/step - loss: 9.4859e-04
# Epoch 23/200
# 6/6 [==============================] - 0s 11ms/step - loss: 9.4093e-04
# Epoch 24/200
# 6/6 [==============================] - 0s 12ms/step - loss: 9.1917e-04
# Epoch 25/200
# 6/6 [==============================] - 0s 12ms/step - loss: 8.9767e-04
# Epoch 26/200
# 6/6 [==============================] - 0s 12ms/step - loss: 8.9318e-04
# Epoch 27/200
# 6/6 [==============================] - 0s 12ms/step - loss: 8
-04
# Epoch 187/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.4237e-04
# Epoch 188/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.4460e-04
# Epoch 189/200
# 6/6 [==============================] - 0s 21ms/step - loss: 5.4114e-04
# Epoch 190/200
# 6/6 [==============================] - 0s 26ms/step - loss: 5.6386e-04
# Epoch 191/200
# 6/6 [==============================] - 0s 13ms/step - loss: 5.5574e-04
# Epoch 192/200
# 6/6 [==============================] - 0s 13ms/step - loss: 5.3928e-04
# Epoch 193/200
# 6/6 [==============================] - 0s 18ms/step - loss: 5.3502e-04
# Epoch 194/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.3884e-04
# Epoch 195/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.3348e-04
# Epoch 196/200
# 6/6 [==============================] - 0s 17ms/step - loss: 5.2792e-04
# Epoch 197/200
# 6/6 [==============================] - 0s 15ms/step - loss: 5.3184e-04
# Epoch 198/200
# 6/6 [==============================] - 0s 14ms/step - loss: 5.2893e-04
# Epoch 199/200
# 6/6 [==============================] - 0s 17ms/step - loss: 5.3040e-04
# Epoch 200/200
# 6/6 [==============================] - 0s 17ms/step - loss: 5.3216e-04

# %%
pred_train = model.predict(X_train)
pred = model.predict(X_test)
# Out:
# 35/35 [==============================] - 3s 5ms/step
# 9/9 [==============================] - 0s 5ms/step

# %%
pred_train = scaler.inverse_transform(pred_train)
pred = scaler.inverse_transform(pred)
y_test = scaler.inverse_transform([y_test])
y_train = scaler.inverse_transform([y_train])

# %%
y_test = y_test.flatten()
y_train = y_train.flatten()

# %%
print("Training Error")
mae = mean_absolute_error(y_train, pred_train)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_train, pred_train))
print("Root Mean Squared Error (RMSE):", rmse)
    
plt.plot(y_train, label = 'actual '+str(ticker))
plt.plot(pred_train, label = 'predicted '+str(ticker))
plt.title("Training Plot")
plt.legend()
plt.show()
# Out:
# Training Error
# Mean Absolute Error (MAE): 1.8942142483132502
# Root Mean Squared Error (RMSE): 2.746527921792542

# %%
print("Testing Error")
mae = mean_absolute_error(y_test, pred)
print("Mean Absolute Error (MAE):", mae)
rmse = sqrt(mean_squared_error(y_test, pred))
print("Root Mean Squared Error (RMSE):", rmse)

plt.plot(y_test, label = 'actual '+str(ticker))
plt.plot(pred, label = 'predicted '+str(ticker))
plt.title("Testing Plot")
plt.legend()
plt.show()
# Out:
# Testing Error
# Mean Absolute Error (MAE): 2.0029267679483023
# Root Mean Squared Error (RMSE): 2.679702760463593

# %% [markdown]
# ## 10 days future prediction without correction

# %%
def predict_future(days, last_input):
    Output = []
#     i = 0
#     while(i<days):
#     print(f'loop runs {i} times')
#         print('before reshape',last_input)
    last_input = last_input.reshape((20, past_values, 1))
#         print('After Reshape',last_input)
    res = model.predict(last_input)
#         last_input = res
    Output.extend(res.tolist())
#         i=i+1
        
#     print(Output)
    Output = scaler.inverse_transform(Output)
#     print(Output)
    return Output
    
future_predictions_1 = predict_future(1, X_test[-20:])
future_predictions_1 = future_predictions_1.flatten()
# Out:
# 1/1 [==============================] - 0s 72ms/step

# %%
day=range(1,21)

# %%
plt.plot(day,future_predictions_1)
plt.show()

# %%
# def predict_future(days, last_input):
#     Output = []
#     i = 0
#     while(i<days):
# #         print('before reshape',last_input)
#         last_input = last_input.reshape((60, past_values, 1))
# #         print('After Reshape',last_input)
#         res = model.predict(last_input)
# #         last_input = res
#         Output.extend(res.tolist())
#         i=i+1
        
#     print(Output)
#     Output = scaler.inverse_transform(Output)
#     print(Output)
#     return Output
    
# future_predictions_half = predict_future(1/2, X_test[-60:])
# future_predictions_half = future_predictions.flatten()

# %%
# def predict_future(days, last_input):
#     Output = []
#     i = 0
#     while(i<days):
# #         print('before reshape',last_input)
#         last_input = last_input.reshape((60, past_values, 1))
# #         print('After Reshape',last_input)
#         res = model.predict(last_input)
# #         last_input = res
#         Output.extend(res.tolist())
#         i=i+1
        
#     print(Output)
#     Output = scaler.inverse_transform(Output)
#     print(Output)
#     return Output
    
# future_predictions_2 = predict_future(2, X_test[-10:])
# future_predictions_2 = future_predictions.flatten()

# %% [markdown]
# # 10 days future predictions with one day correction

# %%
df = yf.download('AMZN', start='2023-10-05', end='2023-11-02')
df = df.reset_index(drop=True)
data = df['Close'].values
print(data)
data = scaler.fit_transform(data.reshape(-1, 1))
output_list = []
for d in data:
#     print('Actual Price',d)
    inp = d.reshape((1,1,1))
    pred = model.predict(inp)
#     print('Predicted Price',pred)
    pred1 = scaler.inverse_transform(pred)
    output_list.extend(pred1.tolist())
#     print('Predicted Price after inverse scaler',pred1)

print(output_list)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [125.95999908 127.95999908 128.25999451 129.47999573 131.83000183
#  132.33000183 129.78999329 132.55000305 131.47000122 128.13000488
#  128.3999939  125.16999817 126.55999756 128.55999756 121.38999939
#  119.56999969 127.73999786 132.71000671 133.08999634 137.        ]
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 45ms/step
# [[125.97657012939453], [127.97740173339844], [128.27685546875], [129.4920196533203], [131.81689453125], [132.30813598632812], [129.80001831054688], [132.52386474609375], [131.4623565673828], [128.14712524414062], [128.41651916503906], [125.18496704101562], [126.57746124267578], [128.57608032226562], [121.40155792236328], [119.590576171875], [127.7576675415039], [132.6805877685547], [133.0521697998047], [136.8182830810547]]

# %%
day = range(1,21)

# %%
plt.title('Future Predictions with one day correction')
plt.plot(day,output_list)
plt.show()

# %% [markdown]
# # 10 days future predictions with two days correction

# %%
df = yf.download('AMZN', start='2023-10-05', end='2023-11-02')
# print(df)

data1 = df['Close'].values
# print(data1)

data = scaler.fit_transform(data1.reshape(-1, 1))
print(data)
# print(data[0][0])
# print(data[1][0])
output_list_2 = []
for d in range(len(data+2)):
    try:
        inp = np.array([data[d][0],data[d+1][0]])
        inp1 = inp.reshape((1,2,1))
#         pred = model.predict([inp1,inp2])
        pred = model.predict(inp1)
#         print(pred)
        pred = scaler.inverse_transform(pred)
        output_list_2.extend(pred.tolist())
#         print(output_list_2)
    except:
        print('error')

print(output_list_2)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [[0.36660925]
#  [0.48135394]
#  [0.49856538]
#  [0.56855972]
#  [0.70338508]
#  [0.73207125]
#  [0.586345  ]
#  [0.74469324]
#  [0.682731  ]
#  [0.49110758]
#  [0.50659748]
#  [0.32128505]
#  [0.40103257]
#  [0.51577726]
#  [0.10441765]
#  [0.        ]
#  [0.46873196]
#  [0.75387302]
#  [0.77567392]
#  [1.        ]]
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# error
# [[136.0175018310547], [140.56915283203125], [142.3868408203125], [147.14576721191406], [152.32809448242188], [151.0143280029297], [148.4448699951172], [152.97560119628906], [147.73464965820312], [141.064453125], [138.45742797851562], [132.9138946533203], [137.8951416015625], [135.02938842773438], [117.5845718383789], [121.96664428710938], [144.3957977294922], [154.72732543945312], [158.7864990234375]]

# %%
day = range(1,20)

# %%
plt.title('Future Predictions with two day correction')
plt.plot(day,output_list_2)
plt.show()

# %%
ticker = "AMZN"
start='2023-10-05'
end='2023-11-02'
df = yf.download(ticker, start=start, end=end)
d = df['Close'].values
print(d)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [125.95999908 127.95999908 128.25999451 129.47999573 131.83000183
#  132.33000183 129.78999329 132.55000305 131.47000122 128.13000488
#  128.3999939  125.16999817 126.55999756 128.55999756 121.38999939
#  119.56999969 127.73999786 132.71000671 133.08999634 137.        ]

# %%
# day_new=np.arange(1,103)
# day_actual = np.arange(101,111)
# day_pred=np.arange(101,111)
# day_2=np.arange(101,110)

# %%
day_actual = np.arange(1,21)
day_pred=np.arange(1,21)
day_pred2=np.arange(1,21)
day_2=np.arange(1,20)

# %%
plt.title(f'Plot from {start} till {end} for single price value per day')
plt.xlabel('No. of Days')
plt.ylabel('Price Values')
plt.plot(day_actual,d, label = 'actual price', color='blue')
plt.plot(day_pred,future_predictions_1, label = 'without correction', color='red')
# plt.plot(day_pred2,output_list, label = 'with one day correction', color='green')
# plt.plot(day_2,output_list_2, label = 'with two day correction', color='purple')
plt.legend()
plt.show()

# %%
print("Without Correction Data:\n",future_predictions_1,"\n")
print("With One Day Correction:\n",output_list,"\n")
print("With Two Day Correction:\n",output_list_2,"\n")
print("Actual Data:\n",d,"\n")
# Out:
# Without Correction Data:
#  [135.44062665 137.91389733 138.29104325 143.11704676 141.26562643
#  144.84763041 144.71915205 140.43327422 140.02685654 137.69551187
#  135.37104755 129.43840259 129.22906761 131.37130568 126.09700114
#  126.09700114 126.09700114 127.2345615  129.56797668 124.83913418]
#
# With One Day Correction:
#  [[125.97657012939453], [127.97740173339844], [128.27685546875], [129.4920196533203], [131.81689453125], [132.30813598632812], [129.80001831054688], [132.52386474609375], [131.4623565673828], [128.14712524414062], [128.41651916503906], [125.18496704101562], [126.57746124267578], [128.57608032226562], [121.40155792236328], [119.590576171875], [127.7576675415039], [132.6805877685547], [133.0521697998047], [136.8182830810547]]
#
# With Two Day Correction:
#  [[136.0175018310547], [140.56915283203125], [142.3868408203125], [147.14576721191406], [152.32809448242188], [151.0143280029297], [148.4448699951172], [152.97560119628906], [147.73464965820312], [141.064453125], [138.45742797851562], [132.9138946533203], [137.8951416015625], [135.02938842773438], [117.5845718383789], [121.96664428710938], [144.3957977294922], [154.72732543945312], [158.7864990234375]]
#
# Actual Data:
#  [125.95999908 127.95999908 128.25999451 129.47999573 131.83000183
#  132.33000183 129.78999329 132.55000305 131.47000122 128.13000488
#  128.3999939  125.16999817 126.55999756 128.55999756 121.38999939
#  119.56999969 127.73999786 132.71000671 133.08999634 137.        ]

# %%
def get_control_vector(val):
    return np.diff(np.sign(np.diff(val)))

def buy_and_sell_bot(val,controls):
    inv = []
    curr_val = 1000
    inds = np.where(controls)[0]
    buy_inds = np.where(controls>0)[0]
    sell_inds = np.where(controls<0)[0]
    max_limit = sell_inds[-1] if sell_inds[-1]>buy_inds[-1] else buy_inds[-1]
    for i in range(buy_inds[0]+2):
        inv.append(curr_val)
    for i in range(buy_inds[0],max_limit+1):
        if controls[i]>0:
            buy_val = val[i+1]
        elif controls[i]<0:
            sell_val = val[i+1]
            curr_val = curr_val*sell_val/buy_val
        inv.append(curr_val)
        
    if max_limit+1!=len(controls):
        for i in range(len(controls)-max_limit-1):
            inv.append(curr_val)
    return inv

# %%
controls_actual = get_control_vector(d)
print(controls_actual)
amount_actual = buy_and_sell_bot(d, controls_actual)
amount_actual
# Out:
# [ 0.  0.  0.  0. -2.  2. -2.  0.  2. -2.  2.  0. -2.  0.  2.  0.  0.  0.]
# [1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1021.265196921155,
#  1021.265196921155,
#  1021.265196921155,
#  1023.4171548756274,
#  1023.4171548756274,
#  1023.4171548756274,
#  1051.1345278974068,
#  1051.1345278974068,
#  1051.1345278974068,
#  1051.1345278974068,
#  1051.1345278974068,
#  1051.1345278974068]

# %%
controls_pred= get_control_vector(future_predictions_1)
amount_pred = buy_and_sell_bot(future_predictions_1, controls_pred)
amount_pred
# Out:
# [1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1025.3565150644697,
#  1042.3539120862583,
#  1042.3539120862583,
#  1042.3539120862583,
#  1042.3539120862583,
#  1042.3539120862583,
#  1071.045989644894]

# %%
plt.plot(amount_actual, label="actual")
plt.plot(amount_pred, label="pred")
plt.legend()
plt.title("Returns")
plt.show()
